# %%
import numpy as np

xpts = np.array([0,4])
ypts = np.array([0,100])

plt.plot(xpts, ypts)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16968\1653544966.py in <module>
#       4 ypts = np.array([0,100])
#       5
# ----> 6 plt.plot(xpts, ypts)
#       7 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import numpy as np

print(np)
# Out:
# <module 'numpy' from 'F:\\anaconda\\lib\\site-packages\\numpy\\__init__.py'>

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

xpts = np.array([0,100])
ypts = np.array([0,100])

plt.plot(xpts, ypts)
plt.show()

# %%
#hello

# %% [markdown]
# # hello
